# %% [markdown]
# # Lesson 4: Persistence and Streaming

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
tool = TavilySearchResults(max_results=2)

# %%
class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

# %%
from langgraph.checkpoint.sqlite import SqliteSaver

memory = SqliteSaver.from_conn_string(":memory:")

# %%
class Agent:
    def __init__(self, model, tools, checkpointer, system=""):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)
        graph.add_node("action", self.take_action)
        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")
        self.graph = graph.compile(checkpointer=checkpointer)
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_openai(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""
model = ChatOpenAI(model="gpt-4o")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="What is the weather in sf?")]

# %%
thread = {"configurable": {"thread_id": "1"}}

# %%
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v['messages'])
# Out:
# [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz', 'function': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 151, 'total_tokens': 173, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_831e067d82', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-73af9f4a-8da7-44d0-a078-b0bd3bb2035f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz'}])]
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz'}
# Back to the model!
# [ToolMessage(content="[{'url': 'https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/july-7', 'content': 'San Francisco sees an average temperature of 16.4°C | 61.5°F in July. Water temperatures average 12.7°C | 54.9°F in the early part of the month, around 13.3°C | 55.9°F mid-month, and about 13.7°C | 56.7°F toward the end.\\n\\nIn July, sunshine in San Francisco averages between 6 hours and 9 hours per day.\\nThe brightest day, 04.07, sees about 9 hours, while the least sunny, 26.07, has only 6 hours.\\nDuring the first third of the month, sunshine averages 8 hours; in the second third, 7 hours; and at the end, 7 hours.\\nThe sunniest 10-day phase runs from 1-10, with 8 hours daily.\\nThe least sunny phase is 21-31, with just 7 hours. [...] | 23. July | 17 °C | 62 °F | 22 °C | 72 °F | 13 °C | 56 °F | 14 °C | 57 °F | 0.1 mm | 0.0 inch. |\\n| 24. July | 17 °C | 62 °F | 22 °C | 72 °F | 13 °C | 55 °F | 14 °C | 57 °F | 0.0 mm | 0.0 inch. |\\n| 25. July | 17 °C | 62 °F | 22 °C | 72 °F | 13 °C | 55 °F | 14 °C | 57 °F | 0.0 mm | 0.0 inch. |\\n| 26. July | 16 °C | 61 °F | 22 °C | 72 °F | 13 °C | 55 °F | 14 °C | 57 °F | 0.0 mm | 0.0 inch. |\\n| 27. July | 16 °C | 61 °F | 22 °C | 72 °F | 13 °C | 55 °F | 14 °C | 57 °F | 0.1 mm | 0.0 inch. |\\n| 28. July | 16 °C | 61 °F | 22 °C | 71 °F | 13 °C | 55 °F | 14 °C | 57 °F | 0.1 mm | 0.0 inch. |\\n| 29. July | 16 °C | 61 °F | 21 °C | 70 °F | 13 °C | 55 °F | 14 °C | 56 °F | 0.1 mm | 0.0 inch. |\\n| 30. July | 16 °C | 61 °F | 22 °C | 71 °F | 13 °C | 55 °F | 14 °C | 56 °F | 0.1 mm | 0.0 inch. | [...] | Max. Temperature °C (°F) | 14 °C  (57.3) °F | 14.9 °C  (58.7) °F | 16.2 °C  (61.2) °F | 17.4 °C  (63.3) °F | 19.2 °C  (66.5) °F | 21.5 °C  (70.8) °F | 21.8 °C  (71.2) °F | 22.2 °C  (71.9) °F | 23.1 °C  (73.6) °F | 21.3 °C  (70.3) °F | 17.1 °C  (62.8) °F | 13.9 °C  (57.1) °F |\\n| Precipitation / Rainfall mm (in) | 113  (4) | 118  (4) | 83  (3) | 40  (1) | 21  (0) | 6  (0) | 2  (0) | 2  (0) | 3  (0) | 25  (0) | 57  (2) | 111  (4) |\\n| Humidity(%) | 79% | 80% | 78% | 72% | 70% | 69% | 74% | 74% | 71% | 70% | 76% | 78% |\\n| Rainy days (d) | 8 | 7 | 6 | 4 | 2 | 1 | 0 | 0 | 0 | 2 | 5 | 7 |\\n| avg. Sun hours (hours) | 5.9 | 6.5 | 7.8 | 9.1 | 9.1 | 9.3 | 7.4 | 6.8 | 7.6 | 7.3 | 6.8 | 5.8 |'}, {'url': 'https://www.weather25.com/amp/north-america/usa/california/san-francisco?page=month&month=July', 'content': 'San Francisco overview\\n San Francisco 14 day weather\\n San Francisco weather in July\\n San Francisco weather in August\\n Long range weather for San Francisco\\n United States\\n England\\n Home\\n\\nSan Francisco\\n\\nWeather in July 2026\\n\\n1. Home\\n2. North America\\n3. United States\\n4. California\\n5. San Francisco\\n6. July\\n\\n# San Francisco weather in July 2026\\n\\nClick on a day for an hourly weather forecast\\n\\nJul 23\\n\\n0 mm\\n\\n22° / 14°Jul 24\\n\\n0 mm\\n\\n20° / 13°Jul 25\\n\\n0 mm\\n\\n20° / 14°Jul 26\\n\\n0 mm\\n\\n20° / 15°Monday\\n\\nJul 27\\n\\n0 mm\\n\\n20° / 14°Tuesday\\n\\nJul 28\\n\\n0 mm\\n\\n20° / 14°Wednesday\\n\\nJul 29\\n\\n0 mm\\n\\n20° / 15°Thursday\\n\\nJul 30\\n\\n0 mm\\n\\n20° / 14°Friday\\n\\nJul 31\\n\\n0 mm\\n\\n20° / 14°Saturday\\n\\nAug 1\\n\\n0 mm\\n\\n20° / 14°Sunday\\n\\nAug 2\\n\\n0 mm\\n\\n21° / 14°Monday\\n\\nAug 3\\n\\n0 mm\\n\\n20° / 14°Tuesday\\n\\nAug 4\\n\\n0 mm\\n\\n20° / 15°Wednesday\\n\\nAug 5\\n\\n0 mm [...] Aug 4\\n\\n0 mm\\n\\n20° / 15°Wednesday\\n\\nAug 5\\n\\n0 mm\\n\\n21° / 15° Next  \\nMonth >>\\n\\n## The average weather in San Francisco in July\\n\\nThe temperatures in San Francisco in July are comfortable with low of 14°C and and high up to 25°C.\\n\\nThere is little to no rain in San Francisco during July, so it’s a lot easier to explore the city. Just remember to dress in warm layers, as it can still get pretty chilly.\\n\\nOur weather forecast can give you a great sense of what weather to expect in San Francisco in July 2026.\\n\\nIf you’re planning to visit San Francisco in ...
# [AIMessage(content="The current weather in San Francisco is comfortable, with temperatures ranging from a low of around 14°C (57°F) to a high of approximately 22°C (72°F). There is little to no rainfall expected. It's advisable to dress in layers, as it can get chilly.", response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 2100, 'total_tokens': 2158, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_9c49562904', 'finish_reason': 'stop', 'logprobs': None}, id='run-0699e3cf-fc5d-4f97-989f-eef5c3cb9120-0')]

# %%
messages = [HumanMessage(content="What about in la?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_zE5fKGQbBChf0CJbmryt64jm', 'function': {'arguments': '{"query":"current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 2170, 'total_tokens': 2192, 'prompt_tokens_details': {'cached_tokens': 2048, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_9c49562904', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-fda93dd2-8adf-4401-9e98-9fb1e0da8ef1-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_zE5fKGQbBChf0CJbmryt64jm'}])]}
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_zE5fKGQbBChf0CJbmryt64jm'}
# Back to the model!
# {'messages': [ToolMessage(content="HTTPError('500 Server Error: Internal Server Error for url: http://jupyter-api-proxy.internal.dlai/rev-proxy/tavily_search/search')", name='tavily_search_results_json', tool_call_id='call_zE5fKGQbBChf0CJbmryt64jm')]}
# {'messages': [AIMessage(content='I encountered an error while trying to retrieve the current weather in Los Angeles. Let me try again.', additional_kwargs={'tool_calls': [{'id': 'call_lD7crv9usFUWtCaT8pPSr9x8', 'function': {'arguments': '{"query":"current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 2237, 'total_tokens': 2280, 'prompt_tokens_details': {'cached_tokens': 2048, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_9c49562904', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-abc32922-aaac-45a7-8e1e-e578861ce0a3-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_lD7crv9usFUWtCaT8pPSr9x8'}])]}
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_lD7crv9usFUWtCaT8pPSr9x8'}
# Back to the model!
# {'messages': [ToolMessage(content="[{'url': 'https://uscityweather.com/weather/Los-Angeles/2026-07-26', 'content': '# Weather Los Angeles\\n\\n 14 Day Forecast\\n\\nSunday, 26 July 2026\\n\\nWeather Icon\\n\\nwind Icon\\n\\n15 km/h\\n\\nhumidity Icon\\n\\nuv Icon\\n\\nUV Index\\n\\nvisibility Icon\\n\\n9.9 km\\n\\nsunrise Icon\\n\\n06:00 AM\\n\\nsunset Icon\\n\\n07:58 PM\\n\\n### Weather Hourly\\n\\nSunday, 26 July 2026\\n\\n00:00\\n\\nWeather Icon 25°\\n\\n🌡️ 26°\\n\\n💧 47%\\n\\n💨 8km/h\\n\\n01:00\\n\\nWeather Icon 25°\\n\\n🌡️ 26°\\n\\n💧 50%\\n\\n💨 10km/h\\n\\n02:00\\n\\nWeather Icon 24°\\n\\n🌡️ 26°\\n\\n💧 54%\\n\\n💨 11km/h\\n\\n03:00\\n\\nWeather Icon 24°\\n\\n🌡️ 25°\\n\\n💧 54%\\n\\n💨 8km/h\\n\\n04:00\\n\\nWeather Icon 24°\\n\\n🌡️ 25°\\n\\n💧 54%\\n\\n💨 5km/h\\n\\n05:00\\n\\nWeather Icon 24°\\n\\n🌡️ 25°\\n\\n💧 55%\\n\\n💨 3km/h\\n\\n06:00\\n\\nWeather Icon 24°\\n\\n🌡️ 25°\\n\\n💧 52%\\n\\n💨 4km/h\\n\\n07:00\\n\\nWeather Icon 25°\\n\\n🌡️ 26°\\n\\n💧 50%\\n\\n💨 4km/h\\n\\n08:00\\n\\nWeather Icon 25°\\n\\n🌡️ 26°\\n\\n💧 48%\\n\\n💨 5km/h\\n\\n09:00\\n\\nWeather Icon 27°\\n\\n🌡️ 27°\\n\\n💧 44%\\n\\n💨 7km/h\\n\\n10:00\\n\\nWeather Icon 29°\\n\\n🌡️ 28°\\n\\n💧 40%\\n\\n💨 9km/h\\n\\n11:00 [...] 🌡️ 26°\\n\\n01:00\\n\\nWeather Icon\\n\\n25°\\n\\n💧 50%\\n\\n💨 10km/h\\n\\n🌡️ 26°\\n\\n02:00\\n\\nWeather Icon\\n\\n24°\\n\\n💧 54%\\n\\n💨 11km/h\\n\\n🌡️ 26°\\n\\n03:00\\n\\nWeather Icon\\n\\n24°\\n\\n💧 54%\\n\\n💨 8km/h\\n\\n🌡️ 25°\\n\\n04:00\\n\\nWeather Icon\\n\\n24°\\n\\n💧 54%\\n\\n💨 5km/h\\n\\n🌡️ 25°\\n\\n05:00\\n\\nWeather Icon\\n\\n24°\\n\\n💧 55%\\n\\n💨 3km/h\\n\\n🌡️ 25°\\n\\n06:00\\n\\nWeather Icon\\n\\n24°\\n\\n💧 52%\\n\\n💨 4km/h\\n\\n🌡️ 25°\\n\\n07:00\\n\\nWeather Icon\\n\\n25°\\n\\n💧 50%\\n\\n💨 4km/h\\n\\n🌡️ 26°\\n\\n08:00\\n\\nWeather Icon\\n\\n25°\\n\\n💧 48%\\n\\n💨 5km/h\\n\\n🌡️ 26°\\n\\n09:00\\n\\nWeather Icon\\n\\n27°\\n\\n💧 44%\\n\\n💨 7km/h\\n\\n🌡️ 27°\\n\\n10:00\\n\\nWeather Icon\\n\\n29°\\n\\n💧 40%\\n\\n💨 9km/h\\n\\n🌡️ 28°\\n\\n11:00\\n\\nWeather Icon\\n\\n30°\\n\\n💧 36%\\n\\n💨 11km/h\\n\\n🌡️ 30°\\n\\n12:00\\n\\nWeather Icon\\n\\n31°\\n\\n💧 34%\\n\\n💨 12km/h\\n\\n🌡️ 30°\\n\\n13:00\\n\\nWeather Icon\\n\\n32°\\n\\n💧 32%\\n\\n💨 14km/h\\n\\n🌡️ 31°\\n\\n14:00\\n\\nWeather Icon\\n\\n33°\\n\\n💧 30%\\n\\n💨 15km/h\\n\\n🌡️ 32°\\n\\n15:00\\n\\nWeather Icon\\n\\n32°\\n\\n💧 31%\\n\\n💨 15km/h\\n\\n🌡️ 32°\\n\\n16:00\\n\\nWeather Icon\\n\\n32°\\n\\n💧 32% [...] 10:00\\n\\nWeather Icon 29°\\n\\n🌡️ 28°\\n\\n💧 40%\\n\\n💨 9km/h\\n\\n11:00\\n\\nWeather Icon 30°\\n\\n🌡️ 30°\\n\\n💧 36%\\n\\n💨 11km/h\\n\\n12:00\\n\\nWeather Icon 31°\\n\\n🌡️ 30°\\n\\n💧 34%\\n\\n💨 12km/h\\n\\n13:00\\n\\nWeather Icon 32°\\n\\n🌡️ 31°\\n\\n💧 32%\\n\\n💨 14km/h\\n\\n14:00\\n\\nWeather Icon 33°\\n\\n🌡️ 32°\\n\\n💧 30%\\n\\n💨 15km/h\\n\\n15:00\\n\\nWeather Icon 32°\\n\\n🌡️ 32°\\n\\n💧 31%\\n\\n💨 15km/h\\n\\n16:00\\n\\nWeather Icon 32°\\n\\n🌡️ 31°\\n\\n💧 32%\\n\\n💨 15km/h\\n\\n17:00\\n\\nWeather Icon 31°\\n\\n🌡️ 31°\\n\\n💧 33%\\n\\n💨 15km/h\\n\\n18:00\\n\\nWeather Icon 30°\\n\\n🌡️ 30°\\n\\n💧 36%\\n\\n💨 13km/h\\n\\n19:00\\n\\nWeather Icon 29°\\n\\n🌡️ 28°\\n\\n💧 40%\\n\\n💨 12km/h\\n\\n20:00\\n\\nWeather Icon 27°\\n\\n🌡️ 27°\\n\\n💧 43%\\n\\n💨 10km/h\\n\\n21:00\\n\\nWeather Icon 27°\\n\\n🌡️ 27°\\n\\n💧 43%\\n\\n💨 9km/h\\n\\n22:00\\n\\nWeather Icon 27°\\n\\n🌡️ 27°\\n\\n💧 44%\\n\\n💨 8km/h\\n\\n23:00\\n\\nWeather Icon 27°\\n\\n🌡️ 27°\\n\\n💧 45%\\n\\n💨 8km/h\\n\\n00:00\\n\\nWeather Icon\\n\\n25°\\n\\n💧 47%\\n\\n💨 8km/h\\n\\n🌡️ 26°\\n\\n01:00\\n\\nWeather Icon\\n\\n25°\\n\\n💧 50%\\n\\n💨 10km/h\\n\\n🌡️ 26°'}, {'url': 'https://www.aqi.in/weather/us/united-states/california/los-angeles', 'content': 'Humidity86 %\\n\\nFeels8 °C\\n\\nCover100 %\\n\\nVisibility10 km\\n\\nWind Speed & Dir.15.5 kmph /  N\\n\\nUV0\\n\\n## Los Angeles 30-Days (July 2026) Weather Forecast\\n\\nSee Hourly\\n\\nSun.Mon.Tue.Wed.Thu.Fri.Sat.\\n\\n1\\n\\nSunny24°14°\\n\\n2\\n\\nSunny30°14°\\n\\n3\\n\\nSunny33°14°\\n\\n4\\n\\nSunny32°14°\\n\\n5\\n\\nSunny31°16°\\n\\n6\\n\\nSunny33°15°\\n\\n7\\n\\nSunny34°15°\\n\\n8\\n\\nSunny34° ...
# {'messages': [AIMessage(content="The current weather in Los Angeles is sunny, with temperatures ranging from a low of 24°C (75°F) to a high of 33°C (91°F). The weather is generally dry with little chance of rain, but it's always good to stay updated.", response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 4647, 'total_tokens': 4701, 'prompt_tokens_details': {'cached_tokens': 2176, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_9c49562904', 'finish_reason': 'stop', 'logprobs': None}, id='run-ccfa0581-f54e-4f01-97ac-35eeb1622e5a-0')]}

# %%
messages = [HumanMessage(content="Which one is warmer?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content='Los Angeles is currently warmer than San Francisco. The temperatures in Los Angeles range from 24°C (75°F) to 33°C (91°F), whereas in San Francisco, they range from around 14°C (57°F) to 22°C (72°F).', response_metadata={'token_usage': {'completion_tokens': 56, 'prompt_tokens': 4713, 'total_tokens': 4769, 'prompt_tokens_details': {'cached_tokens': 4608, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_9c49562904', 'finish_reason': 'stop', 'logprobs': None}, id='run-8f2d9159-81a7-4183-aa91-f79abb9b6de9-0')]}

# %%
messages = [HumanMessage(content="Which one is warmer?")]
thread = {"configurable": {"thread_id": "2"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content="Could you please clarify what you're comparing to determine which is warmer? Are you comparing two specific locations, types of clothing, materials, or something else? Let me know so I can provide the appropriate information.", response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 149, 'total_tokens': 192, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_f9f4fb6dbf', 'finish_reason': 'stop', 'logprobs': None}, id='run-2d928a48-bf16-4544-851c-008fed2e3b68-0')]}

# %% [markdown]
# ## Streaming tokens

# %%
from langgraph.checkpoint.aiosqlite import AsyncSqliteSaver

memory = AsyncSqliteSaver.from_conn_string(":memory:")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="What is the weather in SF?")]
thread = {"configurable": {"thread_id": "4"}}
async for event in abot.graph.astream_events({"messages": messages}, thread, version="v1"):
    kind = event["event"]
    if kind == "on_chat_model_stream":
        content = event["data"]["chunk"].content
        if content:
            # Empty content in the context of OpenAI means
            # that the model is asking for a tool to be invoked.
            # So we only print non-empty content
            print(content, end="|")
# Out:
# /usr/local/lib/python3.11/site-packages/langchain_core/_api/beta_decorator.py:87: LangChainBetaWarning: This API is in beta and may change in the future.
#   warn_beta(
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_GiHnpbt7P6kuX4g2n6imqDXI'}
# Back to the model!
# I| encountered| an| error| while| trying| to| retrieve| the| current| weather| information| for| San| Francisco|.| You| might| want| to| check| a| reliable| weather| website| or| app| for| the| most| up|-to|-date| information|.| If| there's| anything| else| you'd| like| to| know| or| another| way| I| can| assist| you|,| please| let| me| know|!|
