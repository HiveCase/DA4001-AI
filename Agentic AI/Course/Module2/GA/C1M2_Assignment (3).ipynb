# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an expert on {topic}. Write an essay detailed and well structured, dont use em dashes.                
                """ 

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an expert on essay writing.
    You are provided with draft of an eassay:
    
    {draft}
    Give constructive criticism of the draft on - structure, clarity, strength of argument, and writing style.
    """ 

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an expert on essay writing.
    I have written a essay:
    {original_draft}
    
    For which i got some pointers to improve it: 
    {reflection}
    
    Considering all the information above and the pointers to improve, write a well detailed and structured essay.
    """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[
            {
                "role":"user",
                "content":prompt
            }
        ],
        temperature=1.0
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: The Necessity of Government Regulation in Social Media Platforms
#
# Introduction
#
# In the rapidly evolving digital age, social media platforms have transformed the way individuals communicate, share information, and influence societal narratives. These platforms offer unprecedented connectivity, enabling users to engage in global conversations and access a wealth of information instantaneously. However, the power wielded by social media companies raises critical questions about privacy, misinformation, and ethical concerns. This essay explores the necessity of government regulation on social media platforms by examining the current landscape, potential benefits and drawbacks of regulation, and proposing balanced regulatory frameworks.
#
# The Current Landscape
#
# Social media platforms like Facebook, Twitter, Instagram, and TikTok have become fundamental elements of contemporary life, boasting billions of users worldwide. The immense influence of these platforms over public discourse and behavior cannot be overstated. Yet, the lack of substantial regulation has resulted in several significant issues. Misinformation and fake news proliferate widely, impacting democratic processes and public perceptions. Privacy concerns and data breaches frequently emerge, as companies exploit user data for advertising revenue. Moreover, the rise of cyberbullying, hate speech, and extremist content poses significant ethical challenges.
#
# The Case for Regulation
#
# One primary argument in favor of government regulation is the need to protect public interest and ensure the safety and security of users. By establishing clear guidelines, governments can mitigate the spread of harmful content and misinformation. Regulatory measures can also ensure that user data is handled with transparency and confidentiality, thereby protecting privacy rights. Additionally, regulations can foster a more equitable digital space by ensuring platforms are held accountable for discriminatory practices and the dissemination of harmful material.
#
# Regulation can also encourage social media companies to implement stronger content moderation policies. With regulatory frameworks in place, platforms could be incentivized to develop advanced algorithms for detecting and managing harmful content. For example, imposing penalties for non-compliance could compel these companies to invest in more robust systems that prioritize user safety over profit margins.
#
# Furthermore, government regulation can address the monopolistic tendencies of major tech companies. Without regulatory oversight, dominant platforms may engage in anti-competitive practices, stifling innovation and limiting consumer choice. Implementing antitrust regulations could prevent such monopolies, ensuring a diverse and competitive market that benefits the public.
#
# Challenges and Drawbacks of Regulation
#
# Despite the compelling arguments for regulation, challenges remain. One critical concern is the potential threat to freedom of speech and expression. Excessive government intervention could lead to censorship and impede the free flow of ideas, infringing upon fundamental democratic rights. It is essential to strike a balance between regulation and freedom, ensuring that the right to express diverse viewpoints is not compromised.
#
# Moreover, the dynamic nature of technology poses a significant challenge to effective regulation. Social media platforms are constantly evolving, and regulatory measures may struggle to keep pace with technological advancements. Overly rigid regulations could stifle innovation or become obsolete as new platforms emerge or existing ones evolve.
#
# A Balanced Approach to Regulation
#
# To address these challenges, a balanced and flexible regulatory framework is imperative. Governments must collaborate with technology companies, civil society organizations, and independent experts to create adaptable regulations that keep pace with technological innovations while safeguarding public interest. This collaboration should aim to establish clear objectives and guidelines that protect individual rights without stifling creativity and freedom.
#
# Self-regulation by social media companies, under government oversight, can be a viable approach. Platforms could be required to regularly report on their efforts to manage harmful content, privacy measures, and transparency initiatives. An independent regulatory body could assess these reports, ensuring that companies comply with established standards and guidelines.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government is complex and multifaceted. While challenges exist, the potential benefits of regulation—such as protecting public safety, ensuring data privacy, and fostering competitive markets—underscore its necessity. However, achieving a balanced approach requires thoughtful collaboration between governments, tech companies, and civil society. By crafting adaptable regulations that respect individual freedoms, society can harness the positive potential of social media while minimizing its risks. Ultimately, regulation can create a digital landscape that upholds democratic values, protects users, and promotes a healthy exchange of ideas.
#
# 🧠 Feedback:
#
# Here’s some targeted feedback on your draft, organized by the four areas you asked about:
#
# 1. Structure
# • Introduction & Thesis
#   – You open well by framing social media’s reach and risk.
#   – Your central claim (“necessity of government regulation”) could be sharpened into a one-sentence thesis that previews your main reasons (e.g., public safety, privacy, competition).
# • Body Organization
#   – You’ve got clear sections (Current Landscape, Case for, Challenges, Balanced Approach). That’s good.
#   – Consider breaking “Case for Regulation” into two sub-sections—one on harmful content/misinformation and one on data-privacy/monopoly—to mirror your thesis’s points.
#   – Your “Challenges” section is brief; you might pair each challenge with a mini counter-proposal to strengthen your balanced approach.
# • Transitions
#   – Add signposting phrases (“First,” “Moreover,” “In contrast,” etc.) at the start of each paragraph to guide the reader more smoothly.
# • Conclusion
#   – You restate your call for balanced regulation nicely. To close even stronger, you could end with a concrete recommendation or a forward-looking question/vision.
#
# 2. Clarity
# • Definitions
#   – Early on, define what you mean by “regulation” (e.g., content-moderation standards, data-privacy laws, antitrust enforcement).
# • Focus
#   – A few sentences feel slightly general (“unprecedented connectivity,” “ethical challenges”). Whenever possible, name a specific example or case.
# • Conciseness
#   – Watch for redundancies—for instance, “public safety” and “user safety” in the same paragraph—and pick one phrasing.
# • Jargon
#   – You use terms like “antitrust” or “algorithm” comfortably, but briefly clarify them for readers unfamiliar with tech policy.
#
# 3. Strength of Argument
# • Evidence & Examples
#   – Bolster your points with concrete cases: e.g., Cambridge Analytica scandal for privacy; the 2020 U.S. election and viral misinformation; EU’s GDPR as an existing model.
# • Data & Sources
#   – Even a single statistic (percent of adults who say they’ve seen fake news) lends authority.
# • Addressing Counterarguments
#   – You mention free‐speech concerns—great. You could go further by citing critics who argue “the market should self-regulate” and then show why that falls short.
# • Balance
#   – When you propose a “self-regulation under government oversight” model, sketch out one or two concrete guardrails (e.g., an independent ombudsman or regular transparency audits).
#
# 4. Writing Style
# • Tone & Voice
#   – Your tone is appropriately formal and even-handed.
#   – Occasionally you slip into passive voice (“regulations may be stifled”)—active constructions (“overly rigid rules can stifle innovation”) feel stronger.
# • Sentence Variety
#   – Mix shorter, punchy sentences (“Misinformation costs lives.”) with longer explanatory ones to maintain reader engagement.
# • Word Choice
#   – Replace abstract adjectives (“significant,” “substantial”) with more vivid or precise terms (“pervasive,” “systemic”).
# • Flow
#   – Read the essay aloud to catch any awkward phrasing or rhythm breaks—this will help you polish transitions and eliminate filler words.
#
# Overall, you’ve got a solid framework and a balanced perspective. By sharpening your thesis, adding concrete evidence, and tightening the prose, you’ll transform this into a compelling, authoritative essay. Good luck!
# ✍️ Revised:
#
# Title: The Necessity of Government Regulation in Social Media Platforms
#
# Introduction
#
# In the rapidly evolving digital age, social media platforms have transformed the way individuals communicate, share information, and influence societal narratives. Boasting billions of users worldwide, these platforms provide unprecedented connectivity, enabling global conversations and instantaneous access to a wealth of information. However, with great power comes great responsibility—or, rather, a significant risk. The immense influence wielded by social media companies raises critical questions about privacy, misinformation, and ethical concerns. This essay delves into the necessity of government regulation on social media platforms by examining the current landscape, the potential benefits and drawbacks of regulation, and proposing structured regulatory frameworks to balance public safety, privacy, and competitive markets.
#
# The Current Landscape
#
# Social media platforms like Facebook, Twitter, Instagram, and TikTok have become fundamental aspects of contemporary life. The lack of substantial regulation has led to significant challenges. A glaring issue is the widespread proliferation of misinformation and fake news, which can severely impact democratic processes and public perceptions. For example, during the 2020 U.S. election, false narratives were shared extensively, demonstrably affecting the political landscape. Privacy concerns have also emerged, highlighted by the Cambridge Analytica scandal, where personal data was exploited for political advertising. Additionally, these platforms have become hotspots for cyberbullying, hate speech, and extremist content, posing significant ethical challenges that necessitate scrutiny.
#
# The Case for Regulation
#
# Protecting Public Safety and Privacy
#
# Firstly, government regulation is imperative to protect public interest and ensure user safety. By establishing content moderation standards and data-privacy laws, governments can mitigate the spread of harmful content and misinformation. Regulatory measures, such as those seen in the European Union's General Data Protection Regulation (GDPR), ensure that user data is handled with transparency and confidentiality, safeguarding privacy rights.
#
# Addressing Monopolistic Tendencies
#
# Secondly, regulations can address the monopolistic tendencies of major tech companies. Without regulatory oversight, dominant platforms may engage in anti-competitive practices, stifling innovation and limiting consumer choice. Implementing antitrust measures can prevent such monopolies, fostering a diverse and competitive market that benefits the public.
#
# Challenges and Drawbacks of Regulation
#
# Potential Threats to Freedom of Expression
#
# Despite compelling arguments for regulation, challenges persist. A primary concern is the potential threat to freedom of speech and expression. Excessive government intervention could lead to censorship, impeding the free flow of ideas and infringing upon fundamental democratic rights. Therefore, it's crucial to strike a harmonious balance between regulation and freedom, ensuring diverse viewpoints are not compromised.
#
# Technological Dynamism
#
# Moreover, the dynamic nature of technology poses a significant challenge to effective regulation. Social media platforms are continually evolving; therefore, regulatory measures must be adaptable. Overly rigid rules can stifle innovation or become obsolete as new platforms emerge or existing ones evolve.
#
# A Balanced Approach to Regulation
#
# Collaborative Framework Development
#
# Addressing these challenges requires a balanced and flexible regulatory framework. Governments must collaborate with technology companies, civil society organizations, and independent experts to create adaptable regulations that keep pace with technological innovations while safeguarding public interest. This collaboration should aim to establish clear objectives and guidelines that protect individual rights without stifling creativity and freedom.
#
# Self-Regulation under Government Oversight
#
# Self-regulation by social media companies, with government oversight, is a plausible approach. Platforms could regularly report their efforts to manage harmful content and privacy measures. An independent regulatory body could assess these reports, ensuring compliance with established standards. An independent ombudsman or regular transparency audits could serve as concrete guardrails in this model.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government is complex and multifaceted. The potential benefits of regulation—such as protecting public safety, ensuring data privacy, and fostering competitive markets—underscore its necessity. Achieving a balanced approach requires thoughtful collaboration between governments, tech companies, and civil society. By crafting adaptable regulations that respect individual freedoms, society can harness the positive potential of social media while minimizing its risks. Ultimately, regulation can create a digital landscape that upholds democratic values, protects users, and promotes a healthy exchange of ideas. In moving forward, stakeholders must consider: How can we maintain the delicate equilibrium between innovation and regulation to maximize social media's benefits while minimizing harm?

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Necessity of Government Regulation in Social Media Platforms
#
# Introduction
#
# In the rapidly evolving digital age, social media platforms have transformed the way individuals communicate, share information, and influence societal narratives. These platforms offer unprecedented connectivity, enabling users to engage in global conversations and access a wealth of information instantaneously. However, the power wielded by social media companies raises critical questions about privacy, misinformation, and ethical concerns. This essay explores the necessity of government regulation on social media platforms by examining the current landscape, potential benefits and drawbacks of regulation, and proposing balanced regulatory frameworks.
#
# The Current Landscape
#
# Social media platforms like Facebook, Twitter, Instagram, and TikTok have become fundamental elements of contemporary life, boasting billions of users worldwide. The immense influence of these platforms over public discourse and behavior cannot be overstated. Yet, the lack of substantial regulation has resulted in several significant issues. Misinformation and fake news proliferate widely, impacting democratic processes and public perceptions. Privacy concerns and data breaches frequently emerge, as companies exploit user data for advertising revenue. Moreover, the rise of cyberbullying, hate speech, and extremist content poses significant ethical challenges.
#
# The Case for Regulation
#
# One primary argument in favor of government regulation is the need to protect public interest and ensure the safety and security of users. By establishing clear guidelines, governments can mitigate the spread of harmful content and misinformation. Regulatory measures can also ensure that user data is handled with transparency and confidentiality, thereby protecting privacy rights. Additionally, regulations can foster a more equitable digital space by ensuring platforms are held accountable for discriminatory practices and the dissemination of harmful material.
#
# Regulation can also encourage social media companies to implement stronger content moderation policies. With regulatory frameworks in place, platforms could be incentivized to develop advanced algorithms for detecting and managing harmful content. For example, imposing penalties for non-compliance could compel these companies to invest in more robust systems that prioritize user safety over profit margins.
#
# Furthermore, government regulation can address the monopolistic tendencies of major tech companies. Without regulatory oversight, dominant platforms may engage in anti-competitive practices, stifling innovation and limiting consumer choice. Implementing antitrust regulations could prevent such monopolies, ensuring a diverse and competitive market that benefits the public.
#
# Challenges and Drawbacks of Regulation
#
# Despite the compelling arguments for regulation, challenges remain. One critical concern is the potential threat to freedom of speech and expression. Excessive government intervention could lead to censorship and impede the free flow of ideas, infringing upon fundamental democratic rights. It is essential to strike a balance between regulation and freedom, ensuring that the right to express diverse viewpoints is not compromised.
#
# Moreover, the dynamic nature of technology poses a significant challenge to effective regulation. Social media platforms are constantly evolving, and regulatory measures may struggle to keep pace with technological advancements. Overly rigid regulations could stifle innovation or become obsolete as new platforms emerge or existing ones evolve.
#
# A Balanced Approach to Regulation
#
# To address these challenges, a balanced and flexible regulatory framework is imperative. Governments must collaborate with technology companies, civil society organizations, and independent experts to create adaptable regulations that keep pace with technological innovations while safeguarding public interest. This collaboration should aim to establish clear objectives and guidelines that protect individual rights without stifling creativity and freedom.
#
# Self-regulation by social media companies, under government oversight, can be a viable approach. Platforms could be required to regularly report on their efforts to manage harmful content, privacy measures, and transparency initiatives. An independent regulatory body could assess these reports, ensuring that companies comply with established standards and guidelines.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government is complex and multifaceted. While challenges exist, the potential benefits of regulation—such as protecting public safety, ensuring data privacy, and fostering competitive markets—underscore its necessity. However, achieving a balanced approach requires thoughtful collaboration between governments, tech companies, and civil society. By crafting adaptable regulations that respect individual freedoms, society can harness the positive potential of social media while minimizing its risks. Ultimately, regulation can create a digital landscape that upholds democratic values, protects users, and promotes a healthy exchange of ideas.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Here’s some targeted feedback on your draft, organized by the four areas you asked about:
#
# 1. Structure
# • Introduction & Thesis
#   – You open well by framing social media’s reach and risk.
#   – Your central claim (“necessity of government regulation”) could be sharpened into a one-sentence thesis that previews your main reasons (e.g., public safety, privacy, competition).
# • Body Organization
#   – You’ve got clear sections (Current Landscape, Case for, Challenges, Balanced Approach). That’s good.
#   – Consider breaking “Case for Regulation” into two sub-sections—one on harmful content/misinformation and one on data-privacy/monopoly—to mirror your thesis’s points.
#   – Your “Challenges” section is brief; you might pair each challenge with a mini counter-proposal to strengthen your balanced approach.
# • Transitions
#   – Add signposting phrases (“First,” “Moreover,” “In contrast,” etc.) at the start of each paragraph to guide the reader more smoothly.
# • Conclusion
#   – You restate your call for balanced regulation nicely. To close even stronger, you could end with a concrete recommendation or a forward-looking question/vision.
#
# 2. Clarity
# • Definitions
#   – Early on, define what you mean by “regulation” (e.g., content-moderation standards, data-privacy laws, antitrust enforcement).
# • Focus
#   – A few sentences feel slightly general (“unprecedented connectivity,” “ethical challenges”). Whenever possible, name a specific example or case.
# • Conciseness
#   – Watch for redundancies—for instance, “public safety” and “user safety” in the same paragraph—and pick one phrasing.
# • Jargon
#   – You use terms like “antitrust” or “algorithm” comfortably, but briefly clarify them for readers unfamiliar with tech policy.
#
# 3. Strength of Argument
# • Evidence & Examples
#   – Bolster your points with concrete cases: e.g., Cambridge Analytica scandal for privacy; the 2020 U.S. election and viral misinformation; EU’s GDPR as an existing model.
# • Data & Sources
#   – Even a single statistic (percent of adults who say they’ve seen fake news) lends authority.
# • Addressing Counterarguments
#   – You mention free‐speech concerns—great. You could go further by citing critics who argue “the market should self-regulate” and then show why that falls short.
# • Balance
#   – When you propose a “self-regulation under government oversight” model, sketch out one or two concrete guardrails (e.g., an independent ombudsman or regular transparency audits).
#
# 4. Writing Style
# • Tone & Voice
#   – Your tone is appropriately formal and even-handed.
#   – Occasionally you slip into passive voice (“regulations may be stifled”)—active constructions (“overly rigid rules can stifle innovation”) feel stronger.
# • Sentence Variety
#   – Mix shorter, punchy sentences (“Misinformation costs lives.”) with longer explanatory ones to maintain reader engagement.
# • Word Choice
#   – Replace abstract adjectives (“significant,” “substantial”) with more vivid or precise terms (“pervasive,” “systemic”).
# • Flow
#   – Read the essay aloud to catch any awkward phrasing or rhythm breaks—this will help you polish transitions and eliminate filler words.
#
# Overall, you’ve got a solid framework and a balanced perspective. By sharpening your thesis, adding concrete evidence, and tightening the prose, you’ll transform this into a compelling, authoritative essay. Good luck!</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Necessity of Government Regulation in Social Media Platforms
#
# Introduction
#
# In the rapidly evolving digital age, social media platforms have transformed the way individuals communicate, share information, and influence societal narratives. Boasting billions of users worldwide, these platforms provide unprecedented connectivity, enabling global conversations and instantaneous access to a wealth of information. However, with great power comes great responsibility—or, rather, a significant risk. The immense influence wielded by social media companies raises critical questions about privacy, misinformation, and ethical concerns. This essay delves into the necessity of government regulation on social media platforms by examining the current landscape, the potential benefits and drawbacks of regulation, and proposing structured regulatory frameworks to balance public safety, privacy, and competitive markets.
#
# The Current Landscape
#
# Social media platforms like Facebook, Twitter, Instagram, and TikTok have become fundamental aspects of contemporary life. The lack of substantial regulation has led to significant challenges. A glaring issue is the widespread proliferation of misinformation and fake news, which can severely impact democratic processes and public perceptions. For example, during the 2020 U.S. election, false narratives were shared extensively, demonstrably affecting the political landscape. Privacy concerns have also emerged, highlighted by the Cambridge Analytica scandal, where personal data was exploited for political advertising. Additionally, these platforms have become hotspots for cyberbullying, hate speech, and extremist content, posing significant ethical challenges that necessitate scrutiny.
#
# The Case for Regulation
#
# Protecting Public Safety and Privacy
#
# Firstly, government regulation is imperative to protect public interest and ensure user safety. By establishing content moderation standards and data-privacy laws, governments can mitigate the spread of harmful content and misinformation. Regulatory measures, such as those seen in the European Union's General Data Protection Regulation (GDPR), ensure that user data is handled with transparency and confidentiality, safeguarding privacy rights.
#
# Addressing Monopolistic Tendencies
#
# Secondly, regulations can address the monopolistic tendencies of major tech companies. Without regulatory oversight, dominant platforms may engage in anti-competitive practices, stifling innovation and limiting consumer choice. Implementing antitrust measures can prevent such monopolies, fostering a diverse and competitive market that benefits the public.
#
# Challenges and Drawbacks of Regulation
#
# Potential Threats to Freedom of Expression
#
# Despite compelling arguments for regulation, challenges persist. A primary concern is the potential threat to freedom of speech and expression. Excessive government intervention could lead to censorship, impeding the free flow of ideas and infringing upon fundamental democratic rights. Therefore, it's crucial to strike a harmonious balance between regulation and freedom, ensuring diverse viewpoints are not compromised.
#
# Technological Dynamism
#
# Moreover, the dynamic nature of technology poses a significant challenge to effective regulation. Social media platforms are continually evolving; therefore, regulatory measures must be adaptable. Overly rigid rules can stifle innovation or become obsolete as new platforms emerge or existing ones evolve.
#
# A Balanced Approach to Regulation
#
# Collaborative Framework Development
#
# Addressing these challenges requires a balanced and flexible regulatory framework. Governments must collaborate with technology companies, civil society organizations, and independent experts to create adaptable regulations that keep pace with technological innovations while safeguarding public interest. This collaboration should aim to establish clear objectives and guidelines that protect individual rights without stifling creativity and freedom.
#
# Self-Regulation under Government Oversight
#
# Self-regulation by social media companies, with government oversight, is a plausible approach. Platforms could regularly report their efforts to manage harmful content and privacy measures. An independent regulatory body could assess these reports, ensuring compliance with established standards. An independent ombudsman or regular transparency audits could serve as concrete guardrails in this model.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government is complex and multifaceted. The potential benefits of regulation—such as protecting public safety, ensuring data privacy, and fostering competitive markets—underscore its necessity. Achieving a balanced approach requires thoughtful collaboration between governments, tech companies, and civil society. By crafting adaptable regulations that respect individual freedoms, society can harness the positive potential of social media while minimizing its risks. Ultimately, regulation can create a digital landscape that upholds democratic values, protects users, and promotes a healthy exchange of ideas. In moving forward, stakeholders must consider: How can we maintain the delicate equilibrium between innovation and regulation to maximize social media's benefits while minimizing harm?</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
