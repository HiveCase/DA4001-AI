# %% [markdown]
# <a href="https://colab.research.google.com/github/HiveCase/DA4001-AI/blob/main/Assignments/Week2/Week2_Q6to10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('week_2_dataset.csv')
df.sample(5)
# Out:
#               house_type room_count  house_size       location    city  \
# 15            Apartment       2 BHK       766.0  Goregaon East  Mumbai
# 3453  Independent Floor       3 BHK      1350.0      Pitampura   Delhi
# 250           Apartment       2 BHK       952.0        Dhanori    Pune
# 443           Apartment       3 BHK      1500.0   Andheri West  Mumbai
# 2623          Apartment       1 BHK       750.0    Kalyan West  Mumbai
#
#        latitude  longitude  num_bathrooms  num_balconies security_deposit  \
# 15    19.173874  72.873924            NaN            0.0            >100k
# 3453  28.695364  77.153549            3.0            1.0           <=100k
# 250   18.592974  73.901260            2.0            0.0              NaN
# 443   19.135084  72.814613            3.0            0.0                0
# 2623  19.266455  73.137161            NaN            1.0           <=100k
#
#               status  price
# 15    Semi-Furnished  55000
# 3453  Semi-Furnished  40000
# 250   Semi-Furnished  19600
# 443      Unfurnished  80000
# 2623  Semi-Furnished  10000
